# %%
from pathlib import Path
import shutil

PROJECT_ROOT = Path("/Users/harsha/Desktop/PickPocketProjectOfficial")
PBP_CACHE_DIR = PROJECT_ROOT / "_pbpstats_team_minutes_cache"

if PBP_CACHE_DIR.exists():
    shutil.rmtree(PBP_CACHE_DIR)

PBP_CACHE_DIR.mkdir(parents=True, exist_ok=True)

print(f"Reset minutes cache: {PBP_CACHE_DIR}")
# Out:
# ...
# INPUT FILES
# ...
# Main file:              /Users/harsha/Desktop/PickPocketProjectOfficial/fullseasonfeatures_16_17_25_26.csv
# P&R source file:        /Users/harsha/Desktop/PickPocketProjectOfficial/fullseasonfeatures_p_r_ball_handler_16_17_25_26.csv
# PBP minutes cache dir:  /Users/harsha/Desktop/PickPocketProjectOfficial/_pbpstats_team_minutes_cache
# ...
# TRADED PLAYER-SEASON DETECTION
# ...
# P&R source rows:                         3,123
# Unique player-seasons in P&R source:     2,875
# Traded player-seasons detected:          244
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 721
#     718     continue
#     720 if page is None:
# --> 721     client, hb_session, playwright_instance, browser, page = create_hyperbrowser_page()
#     723 team_labels = []
#     725 for _, team_row in group_df.iterrows():
#
# Cell In[2], line 337, in create_hyperbrowser_page()
# ...
